# %%
import pandas as pd

# %%
df = pd.read_csv(f"zomato.csv")
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
# !pip install pymysql

# %%
import pymysql

# %%
from sqlalchemy import create_engine

# %%
from sqlalchemy.engine import URL
from sqlalchemy.dialects.mysql import LONGTEXT

connection_url = URL.create(
    drivername="mysql+pymysql",
    username="root",
    password="badaldon452",
    host="localhost",
    database="zomato_analysis"
)

engine = create_engine(connection_url)

df.to_sql(
    "zomato",
    con=engine,
    index=False,
    dtype={
        "reviews_list": LONGTEXT()
    }
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 14
#       4 connection_url = URL.create(
#       5     drivername="mysql+pymysql",
#       6     username="root",
#    (...)      9     database="zomato_analysis"
#      10 )
#      12 engine = create_engine(connection_url)
# ---> 14 df.to_sql(
#      15     "zomato",
#      16     con=engine,
#      17     index=False,
#      18     dtype={
#      19         "reviews_list": LONGTEXT()
#      20     }
#      21 )
#
# File c:\Users\sumit\anaconda3\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
# ...

# %%
df1 = pd.read_sql("select * from restaurants",con=engine)

# %%
df1.shape
# Out:
# (12494, 14)

# %%
df1.to_csv('restaurants.csv',index=False)

# %%
df2 = pd.read_sql("select * from restaurant_cuisines",con=engine)

# %%
df2.shape
# Out:
# (28821, 4)

# %%
df2.to_csv('restaurant_cuisines.csv',index=False)
